# %%
import pandas as pd

# %%
# prepare your transactional data
transactions = [
    ['bread', 'peanut butter', 'milk', 'fruit', 'jelly'],
    ['bread', 'jelly', 'soda', 'potato chips', 'milk', 'fruit', 'vegetables', 'peanut butter'],
    ['whipped', 'cream', 'fruit', 'chocolate' 'sauce', 'beer'],
    ['steak', 'jelly', 'soda', 'potato chips', 'bread', 'fruit'],
    ['jelly', 'soda', 'peanut butter', 'milk', 'fruit'],
    ['jelly', 'soda', 'potato chips', 'milk', 'bread', 'fruit'],
    ['fruit', 'soda', 'potato chips', 'milk'],
    ['fruit', 'soda', 'peanut butter', 'milk'],
    ['fruit', 'cheese', 'yogurt'],
    ['yogurt', 'vegetables', 'beer']]
print('\n Customer Buying sequence of items....\n')
transactions
# Out:
#  Customer Buying sequence of items....
# [['bread', 'peanut butter', 'milk', 'fruit', 'jelly'],
#  ['bread',
#   'jelly',
#   'soda',
#   'potato chips',
#   'milk',
#   'fruit',
#   'vegetables',
#   'peanut butter'],
#  ['whipped', 'cream', 'fruit', 'chocolate', 'sauce', 'beer'],
#  ['steak', 'jelly', 'soda', 'potato chips', 'bread', 'fruit'],
#  ['jelly', 'soda', 'peanut butter', 'milk', 'fruit'],
#  ['jelly', 'soda', 'potato chips', 'milk', 'bread', 'fruit'],
#  ['fruit', 'soda', 'potato chips', 'milk'],
#  ['fruit', 'soda', 'peanut butter', 'milk'],
#  ['fruit', 'cheese', 'yogurt'],
#  ['yogurt', 'vegetables', 'beer']]

# %%
# 2 convert the list of transactions into binary type data column
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

print("\nlist of transactions into a one-hot encoded...\n")
df
# Out:
# list of transactions into a one-hot encoded...
#     beer  bread  cheese  chocolate  cream  fruit  jelly   milk  peanut butter  \
# 0  False   True   False      False  False   True   True   True           True
# 1  False   True   False      False  False   True   True   True           True
# 2   True  False   False       True   True   True  False  False          False
# 3  False   True   False      False  False   True   True  False          False
# 4  False  False   False      False  False   True   True   True           True
# 5  False   True   False      False  False   True   True   True          False
# 6  False  False   False      False  False   True  False   True          False
# 7  False  False   False      False  False   True  False   True           True
# 8  False  False    True      False  False   True  False  False          False
# 9   True  False   False      False  False  False  False  False          False
#
#    potato chips  sauce   soda  steak  vegetables  whipped  yogurt
# 0         False  False  False  False       False    False   False
# 1          True  False   True  False        True    False   False
# 2         False   True  False  False       False     True   False
# 3          True  False   True   True       False    False   False
# 4         False  False   True  False       False    False   False
# 5          True  False   True  False       False    False   False
# 6          True  False   True  False       False    False   False
# 7         False  False   True  False       False    False   False
# 8         False  False  False  False       False    False    True
# 9         False  False  False  False        True    False    True

# %%
#	Find frequent itemsets using the Apriori algorithm
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print("\n List of frequent items:... \n")
frequent_itemsets
# Out:
#  List of frequent items:...
#     support                      itemsets
# 0       0.4                       (bread)
# 1       0.9                       (fruit)
# 2       0.5                       (jelly)
# 3       0.6                        (milk)
# 4       0.4               (peanut butter)
# 5       0.4                (potato chips)
# 6       0.6                        (soda)
# 7       0.4                (bread, fruit)
# 8       0.4                (bread, jelly)
# 9       0.5                (jelly, fruit)
# 10      0.6                 (milk, fruit)
# 11      0.4        (peanut butter, fruit)
# 12      0.4         (potato chips, fruit)
# 13      0.6                 (soda, fruit)
# 14      0.4                 (milk, jelly)
# 15      0.4                 (soda, jelly)
# 16      0.4         (peanut butter, milk)
# 17      0.5                  (soda, milk)
# 18      0.4          (soda, potato chips)
# 19      0.4         (jelly, bread, fruit)
# 20      0.4          (jelly, milk, fruit)
# 21      0.4          (jelly, soda, fruit)
# 22      0.4  (peanut butter, milk, fruit)
# 23      0.5           (soda, milk, fruit)
# 24      0.4   (soda, potato chips, fruit)

# %%
# generate the association rules
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)
print("\n Association rule list... ")
rules

#can use confidence and lift
# rule should have maximum threshold  & rule should be unknown
# Out:
#  Association rule list...
#                antecedents     consequents  antecedent support  \
# 0                  (bread)         (fruit)                 0.4
# 1                  (bread)         (jelly)                 0.4
# 2                  (jelly)         (bread)                 0.5
# 3                  (jelly)         (fruit)                 0.5
# 4                   (milk)         (fruit)                 0.6
# 5          (peanut butter)         (fruit)                 0.4
# 6           (potato chips)         (fruit)                 0.4
# 7                   (soda)         (fruit)                 0.6
# 8                  (jelly)          (milk)                 0.5
# 9                  (jelly)          (soda)                 0.5
# 10         (peanut butter)          (milk)                 0.4
# 11                  (soda)          (milk)                 0.6
# 12                  (milk)          (soda)                 0.6
# 13          (potato chips)          (soda)                 0.4
# 14          (bread, jelly)         (fruit)                 0.4
# 15          (jelly, fruit)         (bread)                 0.5
# 16          (bread, fruit)         (jelly)                 0.4
# 17                 (jelly)  (bread, fruit)                 0.5
# 18                 (bread)  (jelly, fruit)                 0.4
# 19           (milk, jelly)         (fruit)                 0.4
# 20          (jelly, fruit)          (milk)                 0.5
# 21                 (jelly)   (milk, fruit)                 0.5
# 22           (soda, jelly)         (fruit)                 0.4
# 23          (jelly, fruit)          (soda)                 0.5
# 24                 (jelly)   (soda, fruit)                 0.5
# 25   (peanut butter, milk)         (fruit)                 0.4
# 26  (peanut butter, fruit)          (milk)                 0.4
# 27         (peanut butter)   (milk, fruit)                 0.4
# 28            (soda, milk)         (fruit)                 0.5
# 29           (soda, fruit)          (milk)                 0.6
# 30           (milk, fruit)          (soda)                 0.6
# 31                  (soda)   (milk, fruit)                 0.6
# 32                  (milk)   (soda, fruit)                 0.6
# 33    (soda, potato chips)         (fruit)                 0.4
# 34   (potato chips, fruit)          (soda)                 0.4
# 35          (potato chips)   (soda, fruit)                 0.4
#
#     consequent support  support  confidence      lift  representativity  \
# 0                  0.9      0.4    1.000000  1.111111               1.0
# 1                  0.5      0.4    1.000000  2.000000               1.0
# 2                  0.4      0.4    0.800000  2.000000               1.0
# 3                  0.9      0.5    1.000000  1.111111               1.0
# 4                  0.9      0.6    1.000000  1.111111               1.0
# 5                  0.9      0.4    1.000000  1.111111               1.0
# 6                  0.9      0.4    1.000000  1.111111               1.0
# 7                  0.9      0.6    1.000000  1.111111               1.0
# 8                  0.6      0.4    0.800000  1.333333               1.0
# 9                  0.6      0.4    0.800000  1.333333               1.0
# 10                 0.6      0.4    1.000000  1.666667               1.0
# 11                 0.6      0.5    0.833333  1.388889               1.0
# 12                 0.6      0.5    0.833333  1.388889               1.0
# 13                 0.6      0.4    1.000000  1.666667               1.0
